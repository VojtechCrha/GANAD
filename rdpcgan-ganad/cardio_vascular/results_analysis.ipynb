# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder pre_gen_1)
# AUC Values:
# 0.550855
# 0.571900
# 0.557755
# 0.549609
# 0.521127
# 0.504882
# 0.588900
# 0.520391
# 0.505436
# 0.575409
#
# APR Values:
# 0.547755
# 0.565182
# 0.554218
# 0.550045
# 0.521709
# 0.514382
# 0.577900
# 0.532736
# 0.511127
# 0.564455
#
# Statistics for AUC:
# Mean: 0.5446263636363635
# Median: 0.5502318181818182
# Variance: 0.0009047332130394867
#
# Statistics for APR:
# Mean: 0.5439509090909092
# Median: 0.5488999999999999
# Variance: 0.0005281006831955912
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
# 0.481891
# 0.592155
# 0.484927
# 0.571473
# 0.567627
# 0.584500
# 0.523373
# 0.524245
# 0.590464
# 0.560655
#
# APR Values:
# 0.496582
# 0.583300
# 0.496409
# 0.553036
# 0.560573
# 0.580773
# 0.521864
# 0.527855
# 0.593664
# 0.557773
#
# Statistics for AUC:
# Mean: 0.5481309090909091
# Median: 0.5641409090909091
# Variance: 0.0017445067805325976
#
# Statistics for APR:
# Mean: 0.5471827272727273
# Median: 0.5554045454545453
# Variance: 0.0012302194205693277
#
# ----------------------------------------
#
# Folder control_10)
# AUC Values:
# 0.598055
# 0.504145
# 0.526236
# 0.567645
# 0.569836
# 0.553082
# 0.578727
# 0.583773
# 0.560227
# 0.503855
#
# APR Values:
# 0.573855
# 0.504573
# 0.521745
# 0.550691
# 0.554282
# 0.540718
# 0.565773
# 0.566718
# 0.545855
# 0.509082
#
# Statistics for AUC:
# Mean: 0.5545581818181818
# Median: 0.5639363636363637
# Variance: 0.001075890361799816
#
# Statistics for APR:
# Mean: 0.543329090909091
# Median: 0.5482727272727272
# Variance: 0.0005900786556473802
#
# ----------------------------------------
#
# Folder pre_gen_10)
# AUC Values:
# 0.555364
# 0.573355
# 0.534909
# 0.579009
# 0.565900
# 0.581536
# 0.526600
# 0.541091
# 0.577127
# 0.554418
#
# APR Values:
# 0.540245
# 0.563673
# 0.532245
# 0.564518
# 0.556355
# 0.568773
# 0.532200
# 0.540473
# 0.559873
# 0.550645
#
# Statistics for AUC:
# Mean: 0.5589309090909091
# Median: 0.5606318181818182
# Variance: 0.00038617203305785035
#
# Statistics for APR:
# Mean: 0.5509000000000001
# Median: 0.5534999999999999
# Variance: 0.0001886986593204776
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
# 0.445945
# 0.570791
# 0.498727
# 0.613255
# 0.522909
# 0.555355
# 0.589155
# 0.600191
# 0.564218
# 0.569118
#
# APR Values:
# 0.471682
# 0.565236
# 0.506036
# 0.594518
# 0.517318
# 0.536709
# 0.580845
# 0.588527
# 0.554209
# 0.553536
#
# Statistics for AUC:
# Mean: 0.5529663636363636
# Median: 0.5666681818181819
# Variance: 0.0025760114609733693
#
# Statistics for APR:
# Mean: 0.5468618181818183
# Median: 0.5538727272727273
# Variance: 0.0015436485546372848
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
# 0.476918
# 0.575909
# 0.565273
# 0.558409
# 0.534536
# 0.511864
# 0.555000
# 0.525036
# 0.579982
# 0.503018
#
# APR Values:
# 0.490227
# 0.561500
# 0.556155
# 0.550118
# 0.540527
# 0.513173
# 0.549255
# 0.534145
# 0.563773
# 0.508718
#
# Statistics for AUC:
# Mean: 0.5385945454545455
# Median: 0.5447681818181818
# Variance: 0.0011625831441689656
#
# Statistics for APR:
# Mean: 0.536759090909091
# Median: 0.5448909090909091
# Variance: 0.000620164889807164
#
# ----------------------------------------
#
# Folder post_gen_0.1)
# AUC Values:
# 0.573064
# 0.582609
# 0.509536
# 0.528136
# 0.544591
# 0.556373
# 0.564482
# 0.586700
# 0.528945
# 0.576009
#
# APR Values:
# 0.562409
# 0.576000
# 0.508527
# 0.523818
# 0.532891
# 0.547264
# 0.550155
# 0.575200
# 0.519455
# 0.579282
#
# Statistics for AUC:
# Mean: 0.5550445454545454
# Median: 0.5604272727272728
# Variance: 0.0006891537640036739
#
# Statistics for APR:
# Mean: 0.5475
# Median: 0.5487090909090908
# Variance: 0.0006554091643709823
#
# ----------------------------------------
#
# Folder post_gen_1)
# AUC Values:
# 0.544745
# 0.568973
# 0.475391
# 0.592491
# 0.502836
# 0.549573
# 0.555182
# 0.538455
# 0.568591
# 0.550327
#
# APR Values:
# 0.542227
# 0.548800
# 0.489782
# 0.579836
# 0.511145
# 0.545245
# 0.550855
# 0.536691
# 0.555927
# 0.545155
#
# Statistics for AUC:
# Mean: 0.5446563636363637
# Median: 0.54995
# Variance: 0.0011338325399449056
#
# Statistics for APR:
# Mean: 0.5405663636363636
# Median: 0.5451999999999999
# Variance: 0.0006063458778696065
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
# 0.533091
# 0.535555
# 0.492409
# 0.541791
# 0.558745
# 0.521727
# 0.557718
# 0.545818
# 0.509136
# 0.560127
#
# APR Values:
# 0.532882
# 0.524809
# 0.502164
# 0.534000
# 0.539782
# 0.521918
# 0.549355
# 0.538355
# 0.511736
# 0.549455
#
# Statistics for AUC:
# Mean: 0.5356118181818182
# Median: 0.5386727272727274
# Variance: 0.0005037532424242427
#
# Statistics for APR:
# Mean: 0.5304454545454546
# Median: 0.5334409090909091
# Variance: 0.0002379517355371897
#
# ----------------------------------------
#
# Folder pre_gen_0.1)
# AUC Values:
# 0.532055
# 0.599845
# 0.564345
# 0.550082
# 0.576400
# 0.569109
# 0.537500
# 0.565691
# 0.601682
# 0.530245
#
# APR Values:
# 0.524882
# 0.588727
# 0.557455
# 0.549855
# 0.581336
# 0.554355
# 0.533400
# 0.567282
# 0.589855
# 0.537182
#
# Statistics for AUC:
# Mean: 0.5626954545454546
# Median: 0.5650181818181819
# Variance: 0.0006584984618916429
#
# Statistics for APR:
# Mean: 0.5584327272727274
# Median: 0.5559045454545455
# Variance: 0.0005336720881542706
#
# ----------------------------------------
#
# Folder mid_gen_10)
# AUC Values:
# 0.558227
# 0.530073
# 0.452400
# 0.577700
# 0.474709
# 0.566664
# 0.465991
# 0.495982
# 0.569664
# 0.540491
#
# APR Values:
# 0.555500
# 0.531027
# 0.472527
# 0.563336
# 0.493045
# 0.555455
# 0.496164
# 0.506609
# 0.558564
# 0.543882
#
# Statistics for AUC:
# Mean: 0.52319
# Median: 0.5352818181818183
# Variance: 0.0022187826345270883
#
# Statistics for APR:
# Mean: 0.5276109090909091
# Median: 0.5374545454545454
# Variance: 0.001080316433425162
#
# ----------------------------------------
#
# Folder post_gen_10)
# AUC Values:
# 0.559418
# 0.571500
# 0.563245
# 0.545064
# 0.544227
# 0.572391
# 0.548118
# 0.550645
# 0.544845
# 0.531945
#
# APR Values:
# 0.552436
# 0.561309
# 0.557727
# 0.546164
# 0.542491
# 0.565536
# 0.546100
# 0.545464
# 0.540718
# 0.535600
#
# Statistics for AUC:
# Mean: 0.55314
# Median: 0.5493818181818181
# Variance: 0.00017148187695133178
#
# Statistics for APR:
# Mean: 0.5493545454545454
# Median: 0.5461318181818182
# Variance: 9.235105601469204e-05
#
# ----------------------------------------
