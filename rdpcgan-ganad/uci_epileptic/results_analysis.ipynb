# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder post_gen_1)
# AUC Values:
# 0.370245
# 0.413300
# 0.542245
# 0.607700
# 0.496455
# 0.407155
# 0.395518
# 0.619600
# 0.455236
# 0.449564
#
# APR Values:
# 0.213482
# 0.250000
# 0.342491
# 0.406200
# 0.316482
# 0.244182
# 0.235982
# 0.396564
# 0.278000
# 0.252609
#
# Statistics for AUC:
# Mean: 0.4757018181818182
# Median: 0.4524
# Variance: 0.007803794780532596
#
# Statistics for APR:
# Mean: 0.2935990909090909
# Median: 0.26530454545454546
# Variance: 0.0046888531395775914
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
# 0.604282
# 0.495591
# 0.503291
# 0.347391
# 0.547736
# 0.476173
# 0.431973
# 0.613800
# 0.439327
# 0.469564
#
# APR Values:
# 0.389618
# 0.277727
# 0.320200
# 0.209836
# 0.369627
# 0.309945
# 0.261918
# 0.414655
# 0.251973
# 0.289655
#
# Statistics for AUC:
# Mean: 0.4929127272727273
# Median: 0.48588181818181825
# Variance: 0.006524934365472909
#
# Statistics for APR:
# Mean: 0.30951545454545454
# Median: 0.2998
# Variance: 0.004235109073461894
#
# ----------------------------------------
#
# Folder pre_gen_1)
# AUC Values:
# 0.366918
# 0.395418
# 0.419300
# 0.389936
# 0.366091
# 0.417682
# 0.370518
# 0.442645
# 0.474245
# 0.384873
#
# APR Values:
# 0.220400
# 0.222673
# 0.235327
# 0.228700
# 0.220900
# 0.250445
# 0.229300
# 0.261936
# 0.274164
# 0.237091
#
# Statistics for AUC:
# Mean: 0.4027627272727273
# Median: 0.3926772727272727
# Variance: 0.0012671497052341573
#
# Statistics for APR:
# Mean: 0.23809363636363634
# Median: 0.2323136363636364
# Variance: 0.00033808944077134994
#
# ----------------------------------------
#
# Folder post_gen_10)
# AUC Values:
# 0.466391
# 0.384436
# 0.655491
# 0.452218
# 0.353882
# 0.354255
# 0.365764
# 0.509891
# 0.665200
# 0.357145
#
# APR Values:
# 0.275609
# 0.215155
# 0.482782
# 0.238091
# 0.215036
# 0.231818
# 0.238536
# 0.283636
# 0.428518
# 0.209345
#
# Statistics for AUC:
# Mean: 0.4564672727272727
# Median: 0.41832727272727277
# Variance: 0.014489113300275473
#
# Statistics for APR:
# Mean: 0.28185272727272725
# Median: 0.23831363636363637
# Variance: 0.009154517535353537
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
# 0.480800
# 0.356036
# 0.393382
# 0.389127
# 0.373364
# 0.416173
# 0.378091
# 0.387336
# 0.408955
# 0.438409
#
# APR Values:
# 0.294627
# 0.219236
# 0.226082
# 0.229882
# 0.222782
# 0.233655
# 0.225727
# 0.225355
# 0.237764
# 0.257164
#
# Statistics for AUC:
# Mean: 0.4021672727272728
# Median: 0.3912545454545454
# Variance: 0.0013048175794306734
#
# Statistics for APR:
# Mean: 0.2372272727272727
# Median: 0.22798181818181817
# Variance: 0.0005210003489439858
#
# ----------------------------------------
#
# Folder post_gen_0.1)
# AUC Values:
# 0.419527
# 0.451709
# 0.382000
# 0.479318
# 0.479336
# 0.509855
# 0.511482
# 0.460391
# 0.389327
# 0.460964
#
# APR Values:
# 0.239955
# 0.286727
# 0.253591
# 0.324427
# 0.310873
# 0.310418
# 0.333736
# 0.261536
# 0.228455
# 0.289864
#
# Statistics for AUC:
# Mean: 0.454390909090909
# Median: 0.46067727272727277
# Variance: 0.002039424224058771
#
# Statistics for APR:
# Mean: 0.28395818181818183
# Median: 0.2882954545454546
# Variance: 0.0013360626850321391
#
# ----------------------------------------
#
# Folder pre_gen_0.1)
# AUC Values:
# 0.449391
# 0.381564
# 0.659391
# 0.529100
# 0.517891
# 0.439227
# 0.550909
# 0.581336
# 0.558927
# 0.527236
#
# APR Values:
# 0.284209
# 0.215973
# 0.453545
# 0.325882
# 0.331945
# 0.252573
# 0.388855
# 0.393636
# 0.377191
# 0.315264
#
# Statistics for AUC:
# Mean: 0.5194972727272728
# Median: 0.5281681818181818
# Variance: 0.00627491992745638
#
# Statistics for APR:
# Mean: 0.3339072727272727
# Median: 0.32891363636363635
# Variance: 0.005131461245179062
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
# 0.530245
# 0.406109
# 0.404591
# 0.410200
# 0.357273
# 0.393464
# 0.376573
# 0.420809
# 0.413564
# 0.377673
#
# APR Values:
# 0.334582
# 0.249627
# 0.246736
# 0.243491
# 0.218918
# 0.242891
# 0.226909
# 0.250491
# 0.250545
# 0.224173
#
# Statistics for AUC:
# Mean: 0.40904999999999997
# Median: 0.40535
# Variance: 0.0022044410514233215
#
# Statistics for APR:
# Mean: 0.2488363636363636
# Median: 0.24511363636363637
# Variance: 0.0010456774655647387
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
# 0.395536
# 0.456109
# 0.375018
# 0.558018
# 0.364645
# 0.463764
# 0.420200
# 0.451591
# 0.378864
# 0.409009
#
# APR Values:
# 0.213000
# 0.262136
# 0.219182
# 0.351645
# 0.214918
# 0.233600
# 0.244364
# 0.280936
# 0.232536
# 0.279291
#
# Statistics for AUC:
# Mean: 0.42727545454545457
# Median: 0.41460454545454545
# Variance: 0.003359533738292011
#
# Statistics for APR:
# Mean: 0.25316090909090916
# Median: 0.2389818181818182
# Variance: 0.0018165993030303028
#
# ----------------------------------------
#
# Folder mid_gen_10)
# AUC Values:
# 0.395318
# 0.486927
# 0.374982
# 0.391964
# 0.330736
# 0.576127
# 0.488164
# 0.364700
# 0.488691
# 0.413218
#
# APR Values:
# 0.226009
# 0.269064
# 0.226755
# 0.232791
# 0.215800
# 0.309664
# 0.315800
# 0.219109
# 0.302982
# 0.239636
#
# Statistics for AUC:
# Mean: 0.43108272727272723
# Median: 0.4042681818181818
# Variance: 0.005720598373737371
#
# Statistics for APR:
# Mean: 0.2557609090909091
# Median: 0.23621363636363638
# Variance: 0.0015968183296602382
#
# ----------------------------------------
#
# Folder control_10)
# AUC Values:
# 0.417600
# 0.575900
# 0.372727
# 0.612927
# 0.697473
# 0.550918
# 0.366773
# 0.346891
# 0.310700
# 0.402045
#
# APR Values:
# 0.231082
# 0.366018
# 0.208309
# 0.389964
# 0.510564
# 0.331109
# 0.223509
# 0.220845
# 0.202118
# 0.233209
#
# Statistics for AUC:
# Mean: 0.4653954545454545
# Median: 0.4098227272727273
# Variance: 0.017526262502295678
#
# Statistics for APR:
# Mean: 0.29167272727272725
# Median: 0.23214545454545454
# Variance: 0.010708706409550042
#
# ----------------------------------------
#
# Folder pre_gen_10)
# AUC Values:
# 0.636345
# 0.554873
# 0.521627
# 0.342045
# 0.536273
# 0.657900
# 0.338700
# 0.627900
# 0.395973
# 0.583045
#
# APR Values:
# 0.411282
# 0.371736
# 0.290991
# 0.195545
# 0.325582
# 0.486309
# 0.216182
# 0.464882
# 0.238227
# 0.384936
#
# Statistics for AUC:
# Mean: 0.5194681818181819
# Median: 0.5455727272727273
# Variance: 0.014396757470156106
#
# Statistics for APR:
# Mean: 0.3385672727272727
# Median: 0.34865909090909086
# Variance: 0.010472709278236922
#
# ----------------------------------------
