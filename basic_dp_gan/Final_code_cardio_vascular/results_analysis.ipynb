# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder pre_gen_0.1)
# AUC Values:
#  0.498709
#  0.553573
#  0.490464
#  0.503500
#  0.487782
#  0.471400
#  0.464718
#  0.579164
#  0.517873
#  0.508100
#
# APR Values:
#  0.505982
#  0.565309
#  0.501545
#  0.518436
#  0.501764
#  0.482464
#  0.484791
#  0.566736
#  0.524164
#  0.513509
#
# Statistics for AUC:
# Mean: 0.5075281818181818
# Median: 0.5011045454545454
# Variance: 0.0012524596593204767
#
# Statistics for APR:
# Mean: 0.51647
# Median: 0.5097454545454545
# Variance: 0.0008547564931129473
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
#  0.526664
#  0.450136
#  0.499300
#  0.454191
#  0.548464
#  0.493464
#  0.557891
#  0.565800
#  0.479827
#  0.482545
#
# APR Values:
#  0.538027
#  0.477918
#  0.508536
#  0.468464
#  0.539145
#  0.502418
#  0.547927
#  0.561409
#  0.497145
#  0.499355
#
# Statistics for AUC:
# Mean: 0.5058281818181818
# Median: 0.49638181818181815
# Variance: 0.0017489625610651966
#
# Statistics for APR:
# Mean: 0.5140345454545454
# Median: 0.5054772727272727
# Variance: 0.0009606984903581262
#
# ----------------------------------------
#
# Folder post_gen_10)
# AUC Values:
#  0.555764
#  0.462145
#  0.489645
#  0.524136
#  0.514018
#  0.514064
#  0.509045
#  0.496427
#  0.538673
#  0.545255
#
# APR Values:
#  0.551827
#  0.484382
#  0.501773
#  0.530827
#  0.521418
#  0.527491
#  0.511927
#  0.517309
#  0.537691
#  0.550627
#
# Statistics for AUC:
# Mean: 0.5149172727272727
# Median: 0.5140409090909092
# Variance: 0.0007821681992653806
#
# Statistics for APR:
# Mean: 0.5235272727272727
# Median: 0.5244545454545455
# Variance: 0.0004431344352617084
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
#  0.501882
#  0.514745
#  0.479827
#  0.470855
#  0.458809
#  0.516655
#  0.448109
#  0.460045
#  0.475773
#  0.498491
#
# APR Values:
#  0.504909
#  0.513027
#  0.494582
#  0.495309
#  0.473373
#  0.523027
#  0.464891
#  0.478118
#  0.493845
#  0.510218
#
# Statistics for AUC:
# Mean: 0.482519090909091
# Median: 0.4778
# Variance: 0.0005859866014692394
#
# Statistics for APR:
# Mean: 0.49513000000000007
# Median: 0.4949454545454545
# Variance: 0.00034455779706152496
#
# ----------------------------------------
#
# Folder post_gen_1)
# AUC Values:
#  0.523318
#  0.499400
#  0.512327
#  0.464736
#  0.456918
#  0.524173
#  0.478109
#  0.467482
#  0.498509
#  0.503291
#
# APR Values:
#  0.524173
#  0.502991
#  0.512355
#  0.485345
#  0.477045
#  0.539764
#  0.496764
#  0.478991
#  0.504673
#  0.515164
#
# Statistics for AUC:
# Mean: 0.4928263636363637
# Median: 0.49895454545454543
# Variance: 0.0006016703847566592
#
# Statistics for APR:
# Mean: 0.5037263636363637
# Median: 0.5038318181818182
# Variance: 0.0004037203388429758
#
# ----------------------------------------
#
# Folder pre_gen_1)
# AUC Values:
#  0.536273
#  0.417545
#  0.508027
#  0.478918
#  0.553355
#  0.504864
#  0.551118
#  0.558327
#  0.538591
#  0.511055
#
# APR Values:
#  0.536809
#  0.447745
#  0.524545
#  0.490127
#  0.553818
#  0.507964
#  0.549664
#  0.564036
#  0.534282
#  0.524009
#
# Statistics for AUC:
# Mean: 0.5158072727272727
# Median: 0.5236636363636363
# Variance: 0.0018468452488521558
#
# Statistics for APR:
# Mean: 0.5233000000000001
# Median: 0.5294136363636364
# Variance: 0.0011816805693296599
#
# ----------------------------------------
#
# Folder post_gen_0.1)
# AUC Values:
#  0.481600
#  0.494855
#  0.502655
#  0.501009
#  0.522409
#  0.464791
#  0.483409
#  0.454082
#  0.459791
#  0.553509
#
# APR Values:
#  0.494227
#  0.498000
#  0.523791
#  0.508182
#  0.533473
#  0.483755
#  0.496027
#  0.475673
#  0.477055
#  0.564009
#
# Statistics for AUC:
# Mean: 0.49181090909090913
# Median: 0.48913181818181817
# Variance: 0.0009231186005509641
#
# Statistics for APR:
# Mean: 0.505419090909091
# Median: 0.4970136363636364
# Variance: 0.0007769114499540856
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
#  0.506655
#  0.566109
#  0.556036
#  0.491091
#  0.480218
#  0.497709
#  0.495045
#  0.490173
#  0.441318
#  0.527027
#
# APR Values:
#  0.521000
#  0.566945
#  0.538991
#  0.499164
#  0.504682
#  0.508755
#  0.509991
#  0.497482
#  0.463727
#  0.530882
#
# Statistics for AUC:
# Mean: 0.5051381818181818
# Median: 0.4963772727272728
# Variance: 0.0013402058181818189
#
# Statistics for APR:
# Mean: 0.5141618181818182
# Median: 0.5093727272727273
# Variance: 0.0007680257630854002
#
# ----------------------------------------
#
# Folder mid_gen_10)
# AUC Values:
#  0.536373
#  0.506636
#  0.472945
#  0.523400
#  0.513882
#  0.508855
#  0.507682
#  0.508655
#  0.492509
#  0.460418
#
# APR Values:
#  0.532900
#  0.517464
#  0.491764
#  0.532918
#  0.523618
#  0.512882
#  0.519045
#  0.516991
#  0.496291
#  0.483618
#
# Statistics for AUC:
# Mean: 0.5031354545454546
# Median: 0.5081681818181818
# Variance: 0.0005084519641873279
#
# Statistics for APR:
# Mean: 0.512749090909091
# Median: 0.5172272727272728
# Variance: 0.0002856379100091822
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
#  0.562018
#  0.489036
#  0.507027
#  0.480318
#  0.499473
#  0.498436
#  0.562382
#  0.469282
#  0.506900
#  0.482427
#
# APR Values:
#  0.552673
#  0.507655
#  0.514055
#  0.498609
#  0.509464
#  0.503682
#  0.570636
#  0.491373
#  0.519236
#  0.485673
#
# Statistics for AUC:
# Mean: 0.5057299999999999
# Median: 0.49895454545454543
# Variance: 0.0010299017089072564
#
# Statistics for APR:
# Mean: 0.5153054545454546
# Median: 0.5085590909090909
# Variance: 0.0007146948980716245
#
# ----------------------------------------
#
# Folder control_10)
# AUC Values:
#  0.576918
#  0.487464
#  0.518145
#  0.484818
#  0.543991
#  0.481009
#  0.480382
#  0.509464
#  0.533227
#  0.522000
#
# APR Values:
#  0.564945
#  0.504727
#  0.519373
#  0.501491
#  0.563636
#  0.494182
#  0.489927
#  0.516345
#  0.533891
#  0.516436
#
# Statistics for AUC:
# Mean: 0.5137418181818182
# Median: 0.5138045454545456
# Variance: 0.0010114751551882463
#
# Statistics for APR:
# Mean: 0.5204954545454545
# Median: 0.516390909090909
# Variance: 0.0006986630532598721
#
# ----------------------------------------
#
# Folder pre_gen_10)
# AUC Values:
#  0.514873
#  0.500373
#  0.437282
#  0.464618
#  0.496655
#  0.459600
#  0.575827
#  0.532527
#  0.462400
#  0.448718
#
# APR Values:
#  0.518500
#  0.508155
#  0.461855
#  0.483027
#  0.508264
#  0.479073
#  0.561373
#  0.531127
#  0.489827
#  0.467900
#
# Statistics for AUC:
# Mean: 0.4892872727272728
# Median: 0.48063636363636364
# Variance: 0.0018615434196510548
#
# Statistics for APR:
# Mean: 0.50091
# Median: 0.49899090909090904
# Variance: 0.0009465851505968762
#
# ----------------------------------------
