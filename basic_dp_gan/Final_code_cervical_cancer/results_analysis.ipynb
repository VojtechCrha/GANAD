# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder control_10)
# AUC Values:
#  0.665991
#  0.624682
#  0.482318
#  0.489182
#  0.489373
#  0.679100
#  0.477827
#  0.422236
#  0.340955
#  0.474209
#
# APR Values:
#  0.293491
#  0.158055
#  0.126491
#  0.115336
#  0.071918
#  0.275691
#  0.125136
#  0.108118
#  0.051982
#  0.086900
#
# Statistics for AUC:
# Mean: 0.5145872727272727
# Median: 0.48575
# Variance: 0.011787724631772271
#
# Statistics for APR:
# Mean: 0.14131181818181818
# Median: 0.12023636363636364
# Variance: 0.006612261415059686
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
#  0.567527
#  0.341973
#  0.394827
#  0.495909
#  0.251255
#  0.611827
#  0.322691
#  0.414473
#  0.603682
#  0.276355
#
# APR Values:
#  0.222300
#  0.050736
#  0.094609
#  0.101945
#  0.048791
#  0.136736
#  0.057073
#  0.077836
#  0.216691
#  0.055382
#
# Statistics for AUC:
# Mean: 0.42805181818181814
# Median: 0.40465000000000007
# Variance: 0.01808282865105602
#
# Statistics for APR:
# Mean: 0.10620999999999998
# Median: 0.08622272727272726
# Variance: 0.004327206766758492
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
#  0.589745
#  0.522773
#  0.584164
#  0.692518
#  0.360345
#  0.501636
#  0.605682
#  0.557882
#  0.457827
#  0.571791
#
# APR Values:
#  0.159564
#  0.133982
#  0.165836
#  0.215791
#  0.052764
#  0.090009
#  0.196009
#  0.146445
#  0.104627
#  0.106100
#
# Statistics for AUC:
# Mean: 0.5444363636363636
# Median: 0.5648363636363637
# Variance: 0.008214578053259864
#
# Statistics for APR:
# Mean: 0.1371127272727273
# Median: 0.14021363636363637
# Variance: 0.0024928496271808998
#
# ----------------------------------------
#
# Folder post_gen_1)
# AUC Values:
#  0.397500
#  0.688255
#  0.459373
#  0.556582
#  0.657145
#  0.422155
#  0.595645
#  0.413909
#  0.236318
#  0.642973
#
# APR Values:
#  0.073382
#  0.252709
#  0.093209
#  0.149591
#  0.183064
#  0.100318
#  0.200627
#  0.130791
#  0.040000
#  0.199064
#
# Statistics for AUC:
# Mean: 0.5069854545454545
# Median: 0.5079772727272727
# Variance: 0.020843749314967856
#
# Statistics for APR:
# Mean: 0.14227545454545454
# Median: 0.1401909090909091
# Variance: 0.004449892140495866
#
# ----------------------------------------
#
# Folder mid_gen_10)
# AUC Values:
#  0.448291
#  0.409655
#  0.345245
#  0.512773
#  0.603373
#  0.577118
#  0.602873
#  0.628173
#  0.542291
#  0.314336
#
# APR Values:
#  0.127418
#  0.113545
#  0.078364
#  0.139591
#  0.123445
#  0.207636
#  0.158782
#  0.187664
#  0.159691
#  0.055055
#
# Statistics for AUC:
# Mean: 0.4984127272727272
# Median: 0.5275318181818183
# Variance: 0.01275852626629936
#
# Statistics for APR:
# Mean: 0.1351190909090909
# Median: 0.13350454545454543
# Variance: 0.002166210311294765
#
# ----------------------------------------
#
# Folder pre_gen_0.1)
# AUC Values:
#  0.457055
#  0.619800
#  0.415327
#  0.528209
#  0.518409
#  0.589309
#  0.508936
#  0.429845
#  0.355736
#  0.622555
#
# APR Values:
#  0.113845
#  0.124218
#  0.120764
#  0.145427
#  0.092864
#  0.282000
#  0.236518
#  0.094145
#  0.072645
#  0.222209
#
# Statistics for AUC:
# Mean: 0.5045181818181819
# Median: 0.5136727272727273
# Variance: 0.00812284183654729
#
# Statistics for APR:
# Mean: 0.15046363636363638
# Median: 0.1224909090909091
# Variance: 0.005037438567493111
#
# ----------------------------------------
#
# Folder post_gen_10)
# AUC Values:
#  0.476218
#  0.650736
#  0.416764
#  0.499082
#  0.639609
#  0.158255
#  0.450555
#  0.338673
#  0.437518
#  0.694618
#
# APR Values:
#  0.125809
#  0.172555
#  0.093582
#  0.179682
#  0.222000
#  0.033091
#  0.083800
#  0.105473
#  0.081818
#  0.267236
#
# Statistics for AUC:
# Mean: 0.4762027272727273
# Median: 0.46338636363636365
# Variance: 0.02567614108448118
#
# Statistics for APR:
# Mean: 0.13650454545454543
# Median: 0.1156409090909091
# Variance: 0.005216292786960515
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
#  0.347218
#  0.477800
#  0.593482
#  0.655673
#  0.581909
#  0.545473
#  0.495891
#  0.493064
#  0.453736
#  0.504727
#
# APR Values:
#  0.075655
#  0.144573
#  0.096709
#  0.284009
#  0.268827
#  0.101355
#  0.099555
#  0.163327
#  0.076482
#  0.103645
#
# Statistics for AUC:
# Mean: 0.5148972727272728
# Median: 0.5003090909090909
# Variance: 0.007288135776859504
#
# Statistics for APR:
# Mean: 0.14141363636363635
# Median: 0.10250000000000001
# Variance: 0.005820014550045912
#
# ----------------------------------------
#
# Folder pre_gen_1)
# AUC Values:
#  0.625218
#  0.477191
#  0.565773
#  0.456955
#  0.489264
#  0.507982
#  0.444273
#  0.589809
#  0.474200
#  0.456373
#
# APR Values:
#  0.148345
#  0.123736
#  0.207027
#  0.094718
#  0.109400
#  0.112418
#  0.117736
#  0.167409
#  0.105291
#  0.088255
#
# Statistics for AUC:
# Mean: 0.5087036363636364
# Median: 0.48322727272727284
# Variance: 0.0039489374692378305
#
# Statistics for APR:
# Mean: 0.12743363636363636
# Median: 0.11507727272727275
# Variance: 0.0013471637107438001
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
#  0.516482
#  0.642618
#  0.442827
#  0.562709
#  0.620927
#  0.652718
#  0.361409
#  0.711873
#  0.329536
#  0.575909
#
# APR Values:
#  0.188745
#  0.172564
#  0.071727
#  0.190100
#  0.146118
#  0.204682
#  0.075927
#  0.388700
#  0.073591
#  0.160255
#
# Statistics for AUC:
# Mean: 0.5417009090909091
# Median: 0.5693090909090909
# Variance: 0.01636520790541781
#
# Statistics for APR:
# Mean: 0.16724090909090908
# Median: 0.1664090909090909
# Variance: 0.008687289095500459
#
# ----------------------------------------
#
# Folder pre_gen_10)
# AUC Values:
#  0.555664
#  0.287009
#  0.533073
#  0.691036
#  0.478336
#  0.586709
#  0.506191
#  0.341064
#  0.397391
#  0.501036
#
# APR Values:
#  0.141036
#  0.065318
#  0.130000
#  0.211200
#  0.095618
#  0.219818
#  0.119109
#  0.084127
#  0.079018
#  0.146764
#
# Statistics for AUC:
# Mean: 0.48775090909090907
# Median: 0.5036136363636363
# Variance: 0.014263159691460046
#
# Statistics for APR:
# Mean: 0.12920090909090912
# Median: 0.12455454545454546
# Variance: 0.0028050103296602385
#
# ----------------------------------------
#
# Folder post_gen_0.1)
# AUC Values:
#  0.365782
#  0.493618
#  0.400664
#  0.517809
#  0.450536
#  0.369464
#  0.416582
#  0.571673
#  0.555291
#  0.322636
#
# APR Values:
#  0.085518
#  0.109073
#  0.075455
#  0.090036
#  0.079082
#  0.082882
#  0.062809
#  0.143836
#  0.194327
#  0.050682
#
# Statistics for AUC:
# Mean: 0.44640545454545455
# Median: 0.4335590909090909
# Variance: 0.007290364705234161
#
# Statistics for APR:
# Mean: 0.09736999999999998
# Median: 0.0842
# Variance: 0.0018099924710743797
#
# ----------------------------------------
