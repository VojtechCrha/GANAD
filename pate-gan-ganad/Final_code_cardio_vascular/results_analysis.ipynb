# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder post_gen_0.1)
# AUC Values:
# 0.594509
# 0.567373
# 0.558018
# 0.514482
# 0.563082
# 0.589436
# 0.495109
# 0.548064
# 0.555427
# 0.597409
#
# APR Values:
# 0.592127
# 0.575591
# 0.560391
# 0.525018
# 0.566927
# 0.573636
# 0.514000
# 0.554018
# 0.556791
# 0.590436
#
# Statistics for AUC:
# Mean: 0.5582909090909091
# Median: 0.56055
# Variance: 0.0011046123232323235
#
# Statistics for APR:
# Mean: 0.5608936363636363
# Median: 0.5636590909090909
# Variance: 0.0006459469797979806
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
# Series([], )
#
# APR Values:
# Series([], )
#
# Statistics for AUC:
# Mean: nan
# Median: nan
# Variance: nan
#
# Statistics for APR:
# Mean: nan
# Median: nan
# Variance: nan
#
# ----------------------------------------
#
# Folder pre_gen_1)
# AUC Values:
# Series([], )
#
# APR Values:
# Series([], )
#
# Statistics for AUC:
# Mean: nan
# Median: nan
# Variance: nan
#
# Statistics for APR:
# Mean: nan
# Median: nan
# Variance: nan
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
# Series([], )
#
# APR Values:
# Series([], )
#
# Statistics for AUC:
# Mean: nan
# Median: nan
# Variance: nan
#
# Statistics for APR:
# Mean: nan
# Median: nan
# Variance: nan
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
# 0.562036
# 0.575700
# 0.586009
# 0.602664
# 0.567873
# 0.601945
# 0.599836
# 0.535509
# 0.564791
# 0.552555
#
# APR Values:
# 0.547127
# 0.576873
# 0.578936
# 0.597909
# 0.556218
# 0.599773
# 0.594518
# 0.533873
# 0.555818
# 0.539682
#
# Statistics for AUC:
# Mean: 0.5748918181818181
# Median: 0.5717863636363636
# Variance: 0.0005129068953168047
#
# Statistics for APR:
# Mean: 0.5680727272727273
# Median: 0.5665454545454546
# Variance: 0.0006105576859504126
#
# ----------------------------------------
#
# Folder post_gen_1)
# AUC Values:
# Series([], )
#
# APR Values:
# Series([], )
#
# Statistics for AUC:
# Mean: nan
# Median: nan
# Variance: nan
#
# Statistics for APR:
# Mean: nan
# Median: nan
# Variance: nan
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
# 0.603336
# 0.566709
# 0.552618
# 0.580227
# 0.529118
# 0.565800
# 0.525064
# 0.570491
# 0.573718
# 0.520864
#
# APR Values:
# 0.594582
# 0.575945
# 0.543027
# 0.575118
# 0.534364
# 0.559191
# 0.540827
# 0.566091
# 0.564709
# 0.516709
#
# Statistics for AUC:
# Mean: 0.5587945454545455
# Median: 0.5662545454545455
# Variance: 0.0007122148613406783
#
# Statistics for APR:
# Mean: 0.5570563636363636
# Median: 0.56195
# Variance: 0.0005376657079889806
#
# ----------------------------------------
#
# Folder pre_gen_0.1)
# AUC Values:
# 0.564227
# 0.537891
# 0.562464
# 0.551491
# 0.544809
# 0.552227
# 0.563618
# 0.561536
# 0.572827
# 0.558627
#
# APR Values:
# 0.547091
# 0.527045
# 0.553136
# 0.557409
# 0.545518
# 0.534064
# 0.558436
# 0.575755
# 0.564818
# 0.552873
#
# Statistics for AUC:
# Mean: 0.5569718181818182
# Median: 0.5600818181818181
# Variance: 0.0001073901092745634
#
# Statistics for APR:
# Mean: 0.5516145454545454
# Median: 0.5530045454545455
# Variance: 0.00020115467768595048
#
# ----------------------------------------
