# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder pre_gen_10)
# AUC Values:
# 0.518600
# 0.594573
# 0.519300
# 0.574282
# 0.587964
# 0.496773
# 0.524036
# 0.506936
# 0.536773
# 0.570545
#
# APR Values:
# 0.395955
# 0.453527
# 0.366800
# 0.426482
# 0.456864
# 0.383736
# 0.379836
# 0.356809
# 0.392564
# 0.433082
#
# Statistics for AUC:
# Mean: 0.5429781818181818
# Median: 0.5304045454545454
# Variance: 0.0012679743654729113
#
# Statistics for APR:
# Mean: 0.40456545454545456
# Median: 0.39425909090909095
# Variance: 0.0012662599595959592
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
# 0.562445
# 0.529745
# 0.549945
# 0.559873
# 0.580427
# 0.577545
# 0.603691
# 0.503173
# 0.609727
# 0.560536
#
# APR Values:
# 0.411609
# 0.385482
# 0.401891
# 0.414709
# 0.453164
# 0.423664
# 0.476718
# 0.382536
# 0.474036
# 0.431582
#
# Statistics for AUC:
# Mean: 0.5637109090909089
# Median: 0.561490909090909
# Variance: 0.0010245732929292936
#
# Statistics for APR:
# Mean: 0.42553909090909087
# Median: 0.41918636363636363
# Variance: 0.0011220913507805326
#
# ----------------------------------------
#
# Folder control_10)
# AUC Values:
# 0.600400
# 0.545127
# 0.537282
# 0.531527
# 0.567982
# 0.562745
# 0.613236
# 0.499318
# 0.508209
# 0.564209
#
# APR Values:
# 0.446064
# 0.413918
# 0.403700
# 0.379855
# 0.428182
# 0.443945
# 0.466882
# 0.383573
# 0.382000
# 0.394800
#
# Statistics for AUC:
# Mean: 0.5530036363636364
# Median: 0.5539363636363637
# Variance: 0.001330926009182734
#
# Statistics for APR:
# Mean: 0.41429181818181815
# Median: 0.40880909090909096
# Variance: 0.0009457815325987148
#
# ----------------------------------------
#
# Folder pre_gen_1)
# AUC Values:
# 0.470373
# 0.512718
# 0.473127
# 0.592582
# 0.503300
# 0.664009
# 0.516845
# 0.519209
# 0.554764
# 0.584918
#
# APR Values:
# 0.348764
# 0.396127
# 0.358536
# 0.477855
# 0.372300
# 0.536673
# 0.354491
# 0.368318
# 0.401691
# 0.435355
#
# Statistics for AUC:
# Mean: 0.5391845454545455
# Median: 0.5180272727272728
# Variance: 0.0036390624251606976
#
# Statistics for APR:
# Mean: 0.4050109090909091
# Median: 0.3842136363636364
# Variance: 0.0037715529623507816
#
# ----------------------------------------
#
# Folder post_gen_10)
# AUC Values:
# 0.568291
# 0.539691
# 0.520636
# 0.566745
# 0.591064
# 0.576236
# 0.568609
# 0.563864
# 0.514445
# 0.513100
#
# APR Values:
# 0.425609
# 0.424209
# 0.396082
# 0.430091
# 0.473991
# 0.465836
# 0.413482
# 0.419018
# 0.381036
# 0.385800
#
# Statistics for AUC:
# Mean: 0.5522681818181818
# Median: 0.5653045454545453
# Variance: 0.0007856472222222208
#
# Statistics for APR:
# Mean: 0.4215154545454546
# Median: 0.42161363636363636
# Variance: 0.0009385960339761246
#
# ----------------------------------------
#
# Folder mid_gen_10)
# AUC Values:
# 0.604591
# 0.516682
# 0.505482
# 0.527709
# 0.531627
# 0.560191
# 0.579091
# 0.563909
# 0.545418
# 0.597773
#
# APR Values:
# 0.399291
# 0.374991
# 0.357009
# 0.352582
# 0.408064
# 0.414845
# 0.468464
# 0.446718
# 0.379973
# 0.472200
#
# Statistics for AUC:
# Mean: 0.5532472727272727
# Median: 0.5528045454545455
# Variance: 0.0011386617777777767
#
# Statistics for APR:
# Mean: 0.40741363636363637
# Median: 0.4036772727272727
# Variance: 0.0018824710055096426
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
# 0.586336
# 0.512045
# 0.438982
# 0.621836
# 0.537273
# 0.603327
# 0.523009
# 0.537136
# 0.575418
# 0.566836
#
# APR Values:
# 0.454355
# 0.356955
# 0.335109
# 0.461409
# 0.387564
# 0.476955
# 0.396773
# 0.394391
# 0.447091
# 0.436300
#
# Statistics for AUC:
# Mean: 0.5502200000000002
# Median: 0.5520545454545455
# Variance: 0.00278613395408632
#
# Statistics for APR:
# Mean: 0.41468999999999995
# Median: 0.4165363636363636
# Variance: 0.002253895490358125
#
# ----------------------------------------
#
# Folder post_gen_0.1)
# AUC Values:
# 0.545527
# 0.509482
# 0.602473
# 0.636582
# 0.652582
# 0.587009
# 0.525155
# 0.554864
# 0.588955
# 0.538227
#
# APR Values:
# 0.434527
# 0.376209
# 0.472873
# 0.498773
# 0.524209
# 0.443200
# 0.403664
# 0.408764
# 0.448045
# 0.421945
#
# Statistics for AUC:
# Mean: 0.5740854545454546
# Median: 0.5709363636363636
# Variance: 0.0022555714453627172
#
# Statistics for APR:
# Mean: 0.44322090909090905
# Median: 0.43886363636363634
# Variance: 0.0020353874022038575
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
# 0.547918
# 0.533609
# 0.610636
# 0.543827
# 0.446164
# 0.495845
# 0.552864
# 0.549391
# 0.587827
# 0.510109
#
# APR Values:
# 0.410364
# 0.364300
# 0.482518
# 0.408327
# 0.340145
# 0.356300
# 0.420582
# 0.414155
# 0.394336
# 0.382718
#
# Statistics for AUC:
# Mean: 0.5378190909090909
# Median: 0.5458727272727273
# Variance: 0.002138842818181816
#
# Statistics for APR:
# Mean: 0.39737454545454554
# Median: 0.4013318181818182
# Variance: 0.0016265017410468314
#
# ----------------------------------------
#
# Folder pre_gen_0.1)
# AUC Values:
# 0.472182
# 0.600391
# 0.577018
# 0.515400
# 0.462382
# 0.598455
# 0.567500
# 0.516709
# 0.565300
# 0.564582
#
# APR Values:
# 0.343082
# 0.468600
# 0.440055
# 0.389736
# 0.325482
# 0.465655
# 0.423482
# 0.401200
# 0.428527
# 0.430245
#
# Statistics for AUC:
# Mean: 0.5439918181818182
# Median: 0.5649409090909091
# Variance: 0.0024496795123966917
#
# Statistics for APR:
# Mean: 0.4116063636363637
# Median: 0.42600454545454547
# Variance: 0.002272575427915519
#
# ----------------------------------------
#
# Folder post_gen_1)
# AUC Values:
# 0.542355
# 0.420664
# 0.574427
# 0.626009
# 0.600282
# 0.521809
# 0.611809
# 0.566755
# 0.592564
# 0.538627
#
# APR Values:
# 0.385645
# 0.295109
# 0.465518
# 0.484655
# 0.448064
# 0.385236
# 0.477191
# 0.428245
# 0.449745
# 0.427145
#
# Statistics for AUC:
# Mean: 0.55953
# Median: 0.570590909090909
# Variance: 0.00351303129568411
#
# Statistics for APR:
# Mean: 0.4246554545454545
# Median: 0.43815454545454546
# Variance: 0.003231563534435261
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
# 0.598409
# 0.567245
# 0.592409
# 0.611764
# 0.569045
# 0.598873
# 0.499200
# 0.529255
# 0.557136
# 0.604373
#
# APR Values:
# 0.463791
# 0.466755
# 0.440064
# 0.437827
# 0.430355
# 0.475036
# 0.352973
# 0.387918
# 0.445209
# 0.456036
#
# Statistics for AUC:
# Mean: 0.5727709090909091
# Median: 0.5807272727272728
# Variance: 0.0013153987107438036
#
# Statistics for APR:
# Mean: 0.43559636363636367
# Median: 0.4426363636363636
# Variance: 0.001442640095500458
#
# ----------------------------------------
