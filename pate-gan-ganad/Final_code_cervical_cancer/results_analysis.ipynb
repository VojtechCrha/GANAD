# %%
import numpy as np
import pandas as pd

# %%
import os
import pandas as pd

def process_individual_folder(folder_path):
    auc_values = []
    apr_values = []

    # Iterate over each file in the folder
    for i in range(10):
        file_name = f"results-pategan-{i}.csv"
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path):
            with open(file_path, 'r') as file:
                lines = file.readlines()
                if len(lines) >= 3:
                    auc_values.append(float(lines[1].strip()))
                    apr_values.append(float(lines[2].strip()))

    # Extract the first word of the folder name
    folder_name = os.path.basename(folder_path)
    # print(folder_name.split("_"))
    first_word = folder_name.split("eps=")[0] + folder_name.split("eps=")[1].split("_")[0]

    # Convert to pandas DataFrame for easy calculations
    df = pd.DataFrame({
        'AUC': auc_values,
        'APR': apr_values
    })

    # Print out the values
    print(f"Folder {first_word})")
    print("AUC Values:")
    print(df['AUC'].to_string(index=False))
    print("\nAPR Values:")
    print(df['APR'].to_string(index=False))

    # Calculate and print statistics
    print("\nStatistics for AUC:")
    print(f"Mean: {df['AUC'].mean()}")
    print(f"Median: {df['AUC'].median()}")
    print(f"Variance: {df['AUC'].var()}")

    print("\nStatistics for APR:")
    print(f"Mean: {df['APR'].mean()}")
    print(f"Median: {df['APR'].median()}")
    print(f"Variance: {df['APR'].var()}")
    print("\n" + "-"*40 + "\n")

def process_results_folder(results_folder):
    # Iterate over each subfolder in the results folder
    for subfolder in os.listdir(results_folder):
        subfolder_path = os.path.join(results_folder, subfolder)
        if os.path.isdir(subfolder_path):
            process_individual_folder(subfolder_path)

# Example usage
results_folder = "results"  # Replace with your actual results folder path
process_results_folder(results_folder)
# Out:
# Folder pre_gen_1)
# AUC Values:
# 0.608418
# 0.675800
# 0.449273
# 0.548591
# 0.559536
# 0.752445
# 0.644664
# 0.604818
# 0.728755
# 0.637582
#
# APR Values:
# 0.103164
# 0.168691
# 0.090727
# 0.128918
# 0.148809
# 0.171655
# 0.209491
# 0.167155
# 0.233582
# 0.246727
#
# Statistics for AUC:
# Mean: 0.6209881818181818
# Median: 0.623
# Variance: 0.007962019688705232
#
# Statistics for APR:
# Mean: 0.16689181818181817
# Median: 0.16792272727272728
# Variance: 0.002699247666666665
#
# ----------------------------------------
#
# Folder control_10)
# AUC Values:
# 0.666036
# 0.727818
# 0.678600
# 0.650991
# 0.739818
# 0.552982
# 0.748418
# 0.753991
# 0.625464
# 0.719009
#
# APR Values:
# 0.203718
# 0.195373
# 0.138945
# 0.178264
# 0.286209
# 0.128527
# 0.152600
# 0.332636
# 0.168073
# 0.177136
#
# Statistics for AUC:
# Mean: 0.6863127272727272
# Median: 0.6988045454545453
# Variance: 0.004143333722681365
#
# Statistics for APR:
# Mean: 0.19614818181818183
# Median: 0.1777
# Variance: 0.00422317979889807
#
# ----------------------------------------
#
# Folder post_gen_0.1)
# AUC Values:
# 0.687009
# 0.647627
# 0.743618
# 0.634591
# 0.596900
# 0.462182
# 0.448382
# 0.664736
# 0.561345
# 0.600845
#
# APR Values:
# 0.167518
# 0.295182
# 0.240627
# 0.235764
# 0.217664
# 0.111100
# 0.085555
# 0.277900
# 0.110200
# 0.086345
#
# Statistics for AUC:
# Mean: 0.6047236363636364
# Median: 0.6177181818181818
# Variance: 0.008790638277318638
#
# Statistics for APR:
# Mean: 0.18278545454545453
# Median: 0.1925909090909091
# Variance: 0.006493737340679522
#
# ----------------------------------------
#
# Folder control_0.1)
# AUC Values:
# 0.760009
# 0.631573
# 0.641082
# 0.509764
# 0.578582
# 0.704591
# 0.651373
# 0.625882
# 0.560882
# 0.653482
#
# APR Values:
# 0.407727
# 0.151636
# 0.253200
# 0.092691
# 0.150255
# 0.294236
# 0.185764
# 0.169482
# 0.210482
# 0.110091
#
# Statistics for AUC:
# Mean: 0.6317218181818183
# Median: 0.6363272727272726
# Variance: 0.0050516539247015555
#
# Statistics for APR:
# Mean: 0.20255636363636365
# Median: 0.17762272727272727
# Variance: 0.008939160143250692
#
# ----------------------------------------
#
# Folder mid_gen_1)
# AUC Values:
# 0.614645
# 0.653809
# 0.724309
# 0.749164
# 0.553236
# 0.642200
# 0.515836
# 0.589627
# 0.653045
# 0.660027
#
# APR Values:
# 0.251609
# 0.221791
# 0.248100
# 0.288318
# 0.159582
# 0.258227
# 0.105773
# 0.129136
# 0.155145
# 0.134836
#
# Statistics for AUC:
# Mean: 0.63559
# Median: 0.6476227272727273
# Variance: 0.005080205517906336
#
# Statistics for APR:
# Mean: 0.1952518181818182
# Median: 0.19068636363636365
# Variance: 0.004245478807162534
#
# ----------------------------------------
#
# Folder pre_gen_0.1)
# AUC Values:
# 0.664182
# 0.748345
# 0.696445
# 0.642900
# 0.367655
# 0.664945
# 0.607100
# 0.609418
# 0.454200
# 0.530145
#
# APR Values:
# 0.369682
# 0.349745
# 0.210609
# 0.243136
# 0.071464
# 0.297736
# 0.187718
# 0.191536
# 0.142000
# 0.174691
#
# Statistics for AUC:
# Mean: 0.5985336363636364
# Median: 0.6261590909090908
# Variance: 0.01352500501469238
#
# Statistics for APR:
# Mean: 0.22383181818181824
# Median: 0.2010727272727273
# Variance: 0.008645598168044078
#
# ----------------------------------------
#
# Folder post_gen_10)
# AUC Values:
# 0.747145
# 0.677436
# 0.723145
# 0.694618
# 0.712145
# 0.741527
# 0.710736
# 0.689273
# 0.621809
# 0.649545
#
# APR Values:
# 0.226518
# 0.380291
# 0.162518
# 0.214964
# 0.311191
# 0.244227
# 0.196927
# 0.178564
# 0.169364
# 0.238482
#
# Statistics for AUC:
# Mean: 0.6967381818181818
# Median: 0.7026772727272728
# Variance: 0.0015502158640955026
#
# Statistics for APR:
# Mean: 0.23230454545454543
# Median: 0.2207409090909091
# Variance: 0.004623205863177224
#
# ----------------------------------------
#
# Folder mid_gen_10)
# AUC Values:
# 0.632245
# 0.764682
# 0.655473
# 0.735100
# 0.585936
# 0.738009
# 0.619155
# 0.660355
# 0.619264
# 0.705582
#
# APR Values:
# 0.202027
# 0.369936
# 0.240218
# 0.286682
# 0.130218
# 0.300500
# 0.129091
# 0.124264
# 0.180327
# 0.283436
#
# Statistics for AUC:
# Mean: 0.6715799999999998
# Median: 0.6579136363636364
# Variance: 0.0036694012084481126
#
# Statistics for APR:
# Mean: 0.22467
# Median: 0.22112272727272725
# Variance: 0.007223346594123051
#
# ----------------------------------------
#
# Folder mid_gen_0.1)
# AUC Values:
# 0.445100
# 0.650427
# 0.694191
# 0.669509
# 0.493373
# 0.575409
# 0.537764
# 0.642018
# 0.508255
# 0.726555
#
# APR Values:
# 0.074645
# 0.236064
# 0.274264
# 0.199291
# 0.083218
# 0.190282
# 0.145445
# 0.184473
# 0.095245
# 0.293127
#
# Statistics for AUC:
# Mean: 0.5942600000000001
# Median: 0.6087136363636365
# Variance: 0.009106349663911845
#
# Statistics for APR:
# Mean: 0.17760545454545457
# Median: 0.18737727272727273
# Variance: 0.006012301803489439
#
# ----------------------------------------
#
# Folder control_1)
# AUC Values:
# 0.632591
# 0.679718
# 0.759973
# 0.708291
# 0.605264
# 0.639400
# 0.623473
# 0.730045
# 0.576018
# 0.584409
#
# APR Values:
# 0.125009
# 0.289282
# 0.255864
# 0.199764
# 0.141391
# 0.240764
# 0.215600
# 0.364936
# 0.133636
# 0.155145
#
# Statistics for AUC:
# Mean: 0.6539181818181818
# Median: 0.6359954545454546
# Variance: 0.003947189568411388
#
# Statistics for APR:
# Mean: 0.21213909090909092
# Median: 0.2076818181818182
# Variance: 0.006022470230486684
#
# ----------------------------------------
#
# Folder post_gen_1)
# AUC Values:
# 0.655309
# 0.771482
# 0.572191
# 0.801200
# 0.516964
# 0.669636
# 0.577536
# 0.641900
# 0.525164
# 0.688791
#
# APR Values:
# 0.144600
# 0.342136
# 0.094782
# 0.317818
# 0.097191
# 0.223818
# 0.107145
# 0.223373
# 0.115545
# 0.195036
#
# Statistics for AUC:
# Mean: 0.6420172727272728
# Median: 0.6486045454545455
# Variance: 0.009283797290174471
#
# Statistics for APR:
# Mean: 0.18614454545454545
# Median: 0.16981818181818184
# Variance: 0.008196292588613405
#
# ----------------------------------------
#
# Folder pre_gen_10)
# AUC Values:
# 0.568855
# 0.813345
# 0.563145
# 0.797227
# 0.627255
# 0.744455
# 0.758473
# 0.729755
# 0.673200
# 0.655518
#
# APR Values:
# 0.093145
# 0.398600
# 0.204918
# 0.268927
# 0.146500
# 0.254736
# 0.389573
# 0.192373
# 0.190509
# 0.126782
#
# Statistics for AUC:
# Mean: 0.6931227272727273
# Median: 0.7014772727272727
# Variance: 0.00800278171258035
#
# Statistics for APR:
# Mean: 0.22660636363636363
# Median: 0.19864545454545451
# Variance: 0.010651257631772267
#
# ----------------------------------------
